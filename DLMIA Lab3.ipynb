# %% [markdown]
# <a href="https://colab.research.google.com/github/ASingh-AGH/AI_Collab/blob/main/DLMIA%20Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AGH - Deep Learning in Medical Image Analysis I
#
# Author: Marek Wodziński
#
# Contact: wodzinski@agh.edu.pl
#
# You are allowed to use these materials for all purposes as long as the credit is given.

# %% [markdown]
# # Laboratory 3 - Datasets, Dataloaders

# %% [markdown]
# The goal of the Laboratory 3 is to:
# <ul>
#   <li> Get familiar with loading images using various I/O libraries.
#   <li> Implement several datasets/dataloaders in PyTorch.
#   <li> Understand the parameters and limitations of PyTorch dataloaders.
# </ul>
#
# You are going to start with simple built-in datasets in torchvision to get familiar with the loading hyperparameters. Then, you will implement three datasets/dataloaders using real medical images.

# %% [markdown]
# ### Part I - Basic Dataloaders

# %% [markdown]
# You are going to start with build-in dataset available in **torchvision** - a library dedicated computer vision in PyTorch. It contains several frequently used datasets for prototyping, like MNIST, CIFAR10 and others. You can check the list of available dataset under the following link:
#
# https://pytorch.org/vision/stable/datasets.html
#
# During this laboratory you will use the MNIST dataset.
#
# It is recommended to read:
# https://pytorch.org/tutorials/beginner/basics/data_tutorial.html before continuing.
#
# Let's start with creating the Dataset object:

# %%
import numpy as np
import torch as tc
import matplotlib.pyplot as plt
import torchvision as tv
import os
# !pip install SimpleITK
import SimpleITK as sitk

download = True # Set to True only during the first run or after reseting the notebook, then set to False
train = False # Let's use the testing dataset
root = '/content/MNIST' # Let's download the dataset to the /content folder
transform = tv.transforms.ToTensor() # Used to convert the PIL image to PyTorch Tensor
mnist_dataset = tv.datasets.MNIST(root=  root, train= train, transform=transform,  download= download)# TODO - create the Dataset object

print(f"Testing MNIST dataset length: {len(mnist_dataset)}")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting SimpleITK
#   Downloading SimpleITK-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 9.4 MB/s eta 0:00:00
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-2.2.1
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /content/MNIST/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 80842401.81it/s]
# Extracting /content/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to /content/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /content/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 33884110.16it/s]
# Extracting /content/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz to /content/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /content/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 20969256.32it/s]
# Extracting /content/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz to /content/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /content/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 4413931.60it/s]
# Extracting /content/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz to /content/MNIST/MNIST/raw
#
# Testing MNIST dataset length: 10000

# %% [markdown]
# Now create the assosciated Dataloader:

# %%
batch_size = 16 # The number of cases to be loaded at once
shuffle = False # Whether to load the dataset in random order
num_workers = 2 # The number of CPU cores used by the DataLoader

mnist_dataloader = tc.utils.data.DataLoader(mnist_dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers) #TODO - create the dataloader object

# %% [markdown]
# Now, let's iterate through the dataloader and visualize the first batch.

# %%
figure = plt.figure(figsize=(7, 7))

for images, classes in mnist_dataloader:
    # TODO - implement the visualization below
    for i in range(16):
      figure.add_subplot(4, 4, i+1)
      plt.imshow(images[i][0].squeeze(), cmap="gray")
      plt.axis("off")
      plt.title(classes[i].item())
    break
plt.show()

# %% [markdown]
# You have used a built-in dataset and configured dataloader associated with the dataset. Next, you are going to implement several Dataset objects dedicated to medical images.

# %% [markdown]
# ### Part II - MRI Dataloader (simple)

# %% [markdown]
# In the first part of the laboratory you loaded the built-in MNIST dataset.
#
# However, in practice, you usually have your own dataset. Independent whether the dataset is public or private, it requires a dedicated Dataset object to load the assosciated images/volumes/annotations.
#
# To implement your own Dataset object you need to:
# <ul>
#   <li> Create your own class with the **tc.utils.data.Dataset** as the parent class.
#   <li> Overload the **__init__** function responsible for defining the parameters assosciated with the given Dataset and initializing the logic used during loading.
#   <li> Overload the **__len__** function defining the size of the Dataset (number of cases).
#   <li> Overload the **__getitem__** function responsible for loading a single case within the dataset (images + additional metadata like labels or annotations).
# </ul>
#
# In the first part you are going to use the dataset containing magnetic resonance images of brain dedicated to the tumor classification.
#
# Please download the dataset from:
#
# https://www.kaggle.com/datasets/sartajbhuvaji/brain-tumor-classification-mri?resource=download
#
# , and upload it to your Google Drive or directly to the Google Colaboratory **/content** folder.
#
# If you plan to use the Google Drive (better option), you should:
#
# On the left, under the **Files** bar, find a button called **Mount Drive** and choose your Google Drive.
# It should appear in the **/content** folder as a **drive** or with different name if using non-default settings. Then you will need to unzip the dataset file to a selected path within your Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
input_file = '/content/drive/MyDrive/Colab_Notebooks/Brain_MRI.zip' # Path to the "Brain_MRI.zip"

output_folder = '/content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI' # Path to the folder where you would like to unzip the input ".zip" file

print(f"Input file path: {input_file}")
print(f"Output folder path: {output_folder}")

# !unzip {input_file} -d {output_folder} # Do this only once, them comment out this command
# Out:
# Input file path: /content/drive/MyDrive/Colab_Notebooks/Brain_MRI.zip
# Output folder path: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI
# Archive:  /content/drive/MyDrive/Colab_Notebooks/Brain_MRI.zip
#    creating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/
#    creating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(1).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(10).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(100).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(11).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(12).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(13).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(14).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(15).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(16).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(17).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(18).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(19).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(2).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(20).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(21).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(22).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(23).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(24).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(25).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(26).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(27).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(28).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(29).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(3).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(30).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(31).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(32).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(33).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(34).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(35).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(36).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(37).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(38).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(39).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(4).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(40).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(41).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(42).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(43).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(44).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(45).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(46).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(47).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(48).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(49).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(5).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(50).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(51).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(52).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(53).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(54).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(55).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(56).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(57).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(58).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(59).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(6).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(60).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(61).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(62).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(63).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(64).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(65).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(66).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(67).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(68).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(69).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(7).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(70).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(71).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(72).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(73).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(74).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(75).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(76).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(77).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(78).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(79).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(8).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(80).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(81).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(82).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(83).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(84).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(85).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(86).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(87).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(88).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(89).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(9).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(90).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(91).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(92).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(93).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(94).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(95).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(97).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(98).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image(99).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/glioma_tumor/image.jpg
#    creating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(1).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(10).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(100).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(102).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(106).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(107).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(109).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(11).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(112).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(113).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(118).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(12).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(120).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(121).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(123).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(124).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(125).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(126).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(127).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(13).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(14).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(15).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(16).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(17).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(18).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(19).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(2).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(20).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(21).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(22).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(23).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(24).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(25).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(26).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(27).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(28).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(29).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(3).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(30).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(31).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(32).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(33).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(34).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(35).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(36).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(37).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(38).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(39).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(4).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(40).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(41).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(42).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(43).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(44).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(45).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(46).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(47).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(48).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(49).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(5).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(50).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(51).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(52).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(53).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(54).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image(55).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Testing/meningioma_tumor/image
jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (804).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (805).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (806).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (807).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (808).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (809).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (81).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (810).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (811).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (812).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (813).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (814).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (815).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (816).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (817).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (818).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (819).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (82).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (820).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (821).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (822).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (823).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (824).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (825).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (826).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (827).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (83).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (84).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (85).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (86).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (87).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (88).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (89).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (9).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (90).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (91).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (92).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (93).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (94).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (95).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (96).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (97).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (98).jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Brain_MRI/Brain_MRI/Training/pituitary_tumor/p (99).jpg

# %% [markdown]
# Explore the unzipped data. You should see two folders inside the parent folder: **Training** and **Testing**. Inside these folders you will find four additional folders called: **pituitary_tumor**, **glioma**, **meningioma**, and **no_tumor**. All images inside these folder contain 2-D MRI slices presenting one of the classes.
#
# Please note that the problem is simplfied - the cases are represented only by one 2-D slice from a 3-D MRI volume. In reality - the MRI imagaes are 3-D volumes containing hunderds of 2-D slices for each case.
#
# The next task is to implement a dedicated Dataset object:

# %%
import scipy.ndimage
from skimage import color

class BrainMRIDataset(tc.utils.data.Dataset):
    def __init__(self, dataset_path : str, mode : str="training"):
        self.dataset_path = dataset_path
        self.mode = mode # "training" or "testing"

        if self.mode == "training":
            self.data_path = os.path.join(self.dataset_path, "Training")
        elif self.mode == "testing":
            self.data_path = os.path.join(self.dataset_path, "Testing")
        else:
            raise ValueError("Unsupported mode.")

        self.classes = os.listdir(self.data_path) # Assumption that the classes are represented by the folder names
        print(f"Available classes: {self.classes}")
        self.classes_dict = {self.classes[i]: i for i in range(len(self.classes))}
        print(f"Classes dict: {self.classes_dict}") # Mapping from the classes to numbers

        # Creation of all training cases in the form of list containing tuples with: (path_to_file, class_number)
        self.cases = []
        for current_class in self.classes:
            for current_case in os.listdir(os.path.join(self.data_path, current_class)):
                self.cases.append([ current_case, current_class]) # TODO accumulate the self.cases with (case_path, case_class) pairs

    def __len__(self):
        # Overload the function responsible to determine the size of the dataset
        return len(self.cases)

    def __getitem__(self, idx):
        # Overload the function responsible to load a single image from the dataset
        current_case = self.cases[idx][0]
        current_path = os.path.join(self.data_path, self.cases[idx][1])
        current_class = self.cases[idx][1]
        current_image = tv.io.read_image(os.path.join(current_path, current_case))
        current_image = current_image.type(tc.float32) 

        # All images should have the same resolution
        # Resample the images to the same resolution (224x224), then convert the images to grayscale (if not already) and normalize to [0-1] values

        def resize(current_image): #resample resolution
          return tv.transforms.Resize((224, 224))(current_image)

        def gray(current_image): #grayscale
          return tv.transforms.Grayscale()(current_image)

        current_image = resize(current_image)
        current_image = gray(current_image)
        normalize = lambda image: (image - tc.min(image)) / (tc.max(image) - tc.min(image))
        current_image = normalize(current_image)
        current_image = current_image.unsqueeze(0)
        

        return current_image, current_class

# %% [markdown]
# Now create the DataLoader responsible for loading cases from the Dataset. Notice that you do not have to make any changes with respect to the DataLoader - the interface is the same as long as the Dataset is implemented correctly.

# %%
#minor problem with file naming, had to shift folder, keep in mind when rerunning.

mri_dataset = BrainMRIDataset(dataset_path = output_folder, mode = "testing") #TODO - create the dataset object
batch_size = 16
shuffle = True
mri_dataloader = tc.utils.data.DataLoader(mri_dataset, batch_size=batch_size, shuffle=shuffle) #TODO - create the dataloader object
# Out:
# Available classes: ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
# Classes dict: {'glioma_tumor': 0, 'meningioma_tumor': 1, 'no_tumor': 2, 'pituitary_tumor': 3}

# %% [markdown]
# Finally, verify whether the images are loaded correctly:

# %%
figure = plt.figure(figsize=(10, 10))

for images, classes in mri_dataloader:
    for i in range(16):
        figure.add_subplot(4, 4, i+1)
        plt.imshow(images[i][0].squeeze(), cmap="gray")
        plt.title(classes[i])
        plt.axis("off")
    break
plt.show()

# %% [markdown]
# In this part you implemented a basic dataloader dedicated to MRI images. However, in practice, it is better to make the Dataset object a bit more complicated. This is the task for the next part.

# %% [markdown]
# ### Part III - MRI Dataloader (extended)

# %% [markdown]
# In practice implementing the whole logic in the **__init__** function (as in the example above) is impractical. Better idea is to propose a unified representation and seperate the logic for pairing images with classes or other metadata outside the Dataset object.
#
# The reason for this is connected with the fact that there may be more datasets than one that you would like to use at the same time and split or combine them whenever necessary. This is difficult if the datasets were acquired in different institutions without standarization.
#
# Therefore, now slightly modify the Dataset from the previous Part by using **pandas** library to create and split the input dataset. The **csv** file should contain two columns: relative input path and the corresponding class. This way, you can firstly preprocess different datasets to the same representation and then combine them or split using just the **csv** file.
#
# Note: In practice, for larger dataset, instead of using **csv** files you use tools dedicated to databases.
#
# First, parse the dataset into a csv representation:

# %%
import pandas as pd

dataset_path = output_folder
training_csv_path = os.path.join(dataset_path, "training.csv")
testing_csv_path = os.path.join(dataset_path, "testing.csv")

training_path = os.path.join(dataset_path, "Training")
testing_path = os.path.join(dataset_path, "Testing")

# Repeat the process from the __init__ function to create pandas dataframe
# containing three components: (image_path, image_class_number, image_class_name)

training_classes = os.listdir(training_path) 
testing_classes = os.listdir(testing_path)

classes = training_classes + testing_classes # TODO list all the available classes
print(f"Available classes: {classes}")
classes_dict = {classes[i]: i for i in range(len(classes))}
print(f"Classes dict: {classes_dict}")

training_cases = []
testing_cases = []

for current_class in classes:
    if current_class in training_classes: 
        path = training_path 
        cases = training_cases 
    else: 
        path = testing_path 
        cases = testing_cases

    for current_case in os.listdir(os.path.join(path, current_class)):
        cases.append([current_case, classes_dict[current_class], current_class])

# TODO - create the dataframes and save them to .csv
testing_frame = pd.DataFrame(testing_cases)
testing_frame.to_csv(testing_csv_path)

training_frame = pd.DataFrame(training_cases)
training_frame.to_csv(training_csv_path)
# Out:
# Available classes: ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor', 'glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
# Classes dict: {'glioma_tumor': 4, 'meningioma_tumor': 5, 'no_tumor': 6, 'pituitary_tumor': 7}

# %% [markdown]
# Now modify the Dataset class to use **csv** files instead of implementing the logic inside the **init** function.

# %%
class BrainDataset(tc.utils.data.Dataset):
    def __init__(self, dataset_path, csv_path, transforms=None, z_norm=False):
        self.dataset_path = dataset_path
        self.csv_path = csv_path
        self.dataset_path = dataset_path
        self.dataframe = pd.read_csv(csv_path) # TODO - read the previously created csv

    def __len__(self):
        return self.dataframe.shape[0]

    def __getitem__(self, idx):

        current_class = self.dataframe.iloc[idx, 3]
        data_path = os.path.join(self.dataset_path, current_class)
        current_image = tv.io.read_image(os.path.join(data_path, self.dataframe.iloc[idx, 1]))
        current_label = f"{current_class}: {self.dataframe.iloc[idx, 2]}"
        current_image = current_image.type(tc.float32)

        def resize(current_image): #resample resolution
          return tv.transforms.Resize((224, 224))(current_image)

        def gray(current_image): #grayscale
          return tv.transforms.Grayscale()(current_image)

        current_image = resize(current_image)
        current_image = gray(current_image)
        normalize = lambda image: (image - tc.min(image)) / (tc.max(image) - tc.min(image))
        current_image = normalize(current_image)
        current_image = current_image.unsqueeze(0)
            
        return current_image, current_label

# %% [markdown]
# And now again verify whether everything works correctly by creating the DataLoader and showing an exemplary batch from the training dataset:

# %%
shuffle = True
training_dataset = BrainDataset(os.path.join(dataset_path, "Training"), training_csv_path)
training_dataloader = tc.utils.data.DataLoader(training_dataset, batch_size=batch_size, shuffle=shuffle)
figure = plt.figure(figsize=(10, 10))

for images, classes in training_dataloader:
    for i in range(16):
        figure.add_subplot(4, 4, i+1)
        plt.imshow(images[i][0].squeeze(), cmap="gray")
        plt.title(classes[i])
        plt.axis("off")
    break
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# You should be now familiar with implementing your own Datasets. The next part is for you to train - you are going to implement another one from scratch, without any additional guides.

# %% [markdown]
# ### Part IV - Endoscopy Dataloader

# %% [markdown]
# In this part you are going to implement dataset dedicated to image segmentation (to be then used during Laboratory 6).
#
# The dataset is dedicated to the segmentation of surgical instruments from endoscopy images and comes from:
#
# https://www.kaggle.com/datasets/debeshjha1/kvasirinstrument
#
# We will use the dataset during Laboratory 6 because endoscopy images are relatively low resolution 2-D images than can be easily processed using Google Colaboratory. In reality they are video sequences, however, you are going to process just single frames.
#
# Download the dataset and repeat the steps from the previous parts of the laboratory. Start with creating the dataset:

# %%
# TODO - implement your own dataset object for the endoscopy images
# (together with preprocessing the dataset to the .csv files and unzipping the archive on Google Colab)
from google.colab import drive
drive.mount('/content/drive')

input_file = '/content/drive/MyDrive/Colab_Notebooks/Instruments_Endoscopy.zip'  # Path to the "archive.zip"
output_folder = '/content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy' # Path to the folder where you would like to unzip the input ".zip" file

print(f"Input file path: {input_file}")
print(f"Output folder path: {output_folder}")

# !unzip {input_file} -d {output_folder} # Do this only once, them comment out this command
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Input file path: /content/drive/MyDrive/Colab_Notebooks/Instruments_Endoscopy.zip
# Output folder path: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy
# Archive:  /content/drive/MyDrive/Colab_Notebooks/Instruments_Endoscopy.zip
#    creating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/bboxes.json
#    creating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/
#    creating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu8ty6z00003b5yzfaezbs5.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu8v7pr00013b5ymfi2z7uf.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu8w7vy00023b5y3vt2wczx.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu8xad600033b5yc78xfyjx.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu99qx200043b5yd2c5g84t.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu9ejjf00053b5y4mf7bilw.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu9ij2e00063b5yrrbb3f2o.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu9j9vo00073b5y3m92mu6n.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu9jucf00083b5ytpqoue72.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu9ksoq00093b5ylw5wwfr2.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu9lvft000a3b5yb79pnr64.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu9mtrc000b3b5y826amhgq.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu9newl000c3b5ynkam0whb.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu9qend000d3b5y0mgn5fhw.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu9r72l000e3b5yerhwmjut.jpg
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/images/images/ckcu
png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jb6ew00103b5ymc5cgal1.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jbwfl00113b5yu6fq9n0y.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jcl8s00123b5yifl4o1dp.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jd9w400133b5y9vxx0b03.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jdvai00143b5yy3phakue.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jepc400153b5yhiam06ww.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jh72i00173b5ysqfcv9s7.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jj2y400193b5ye5y7pxsk.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jjigh001a3b5yioe9tntx.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jklkj001b3b5y0zjsxb0p.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jl4mp001c3b5yujvme2g8.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jlomu001d3b5yn3q8wnf8.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jmdk7001e3b5yj8s1c8nb.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jmsy5001f3b5y6wg7kdh5.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jnoxg001g3b5y1fnq6ytr.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4joc8s001h3b5yh0onvk2s.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jpw6a001i3b5ydut2dd0y.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jqnzs001j3b5ypzul09gf.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jrgi8001k3b5yzjzb18cc.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4jsntf001l3b5y0tp5qm19.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4k27ik00003b5yjwqkoxk7.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4k2sze00013b5yshp9kt3s.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4k3fo300023b5ykc6tnx4q.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4k4js100033b5ydcmw6rjo.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4k54t100043b5yaed05vkq.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4k5uuu00053b5y4471ldol.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4k6mdn00063b5y0rglqtki.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4k7ab000073b5ye56s726v.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4k7rhg00083b5yjdc2m90f.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4k8gpw00093b5yxi6g3tg8.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4ka6fx000a3b5y5l4rc1b0.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4kazw6000b3b5yi8v2d3mi.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4kbkjq000c3b5yyj14oyeg.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4kci5x000d3b5y6ywvphuf.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4kcz9m000e3b5y4maj6x0l.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4kdok6000f3b5ydais95lp.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4ke7ol000g3b5yfa5ziymm.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/masks/masks/ckd4kgex0000h3b5yhpwjd11l.png
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/test.txt
#   inflating: /content/drive/MyDrive/Colab_Notebooks/lab_3_Instruments_Endoscopy/Instruments_Endoscopy/kvasir-instrument/train.txt

# %% [markdown]
# Then create the dataloader:

# %%
# AGAIN SAME ISSUE WIITH FILE NAMING AUTOMATICALLY<< KEEP IN MIND TO CHECK MANUALLY

import pandas as pd
import scipy.ndimage
from skimage import color

data_path = os.path.join(output_folder, "kvasir-instrument")
path_to_images = os.path.join(data_path, "images/images")
path_to_masks = os.path.join(data_path, "masks/masks")
matched_csv_path = os.path.join(data_path, "matched.csv")
images_cases = os.listdir(path_to_images) 

matched_cases=[]
for image in images_cases:
    image_path = os.path.join(path_to_images, image) 
    mask_path = os.path.join(path_to_masks, image.replace("jpg","png"))
    matched_cases.append([image_path, mask_path])

dataframe = pd.DataFrame(matched_cases, columns=["Image_Path", "Mask_Path"])
print(dataframe.head())
dataframe.to_csv(matched_csv_path, index=False)
# Out:
#                                           Image_Path  \
# 0  /content/drive/MyDrive/Colab_Notebooks/lab_3_I...
# 1  /content/drive/MyDrive/Colab_Notebooks/lab_3_I...
# 2  /content/drive/MyDrive/Colab_Notebooks/lab_3_I...
# 3  /content/drive/MyDrive/Colab_Notebooks/lab_3_I...
# 4  /content/drive/MyDrive/Colab_Notebooks/lab_3_I...
#
#                                            Mask_Path
# 0  /content/drive/MyDrive/Colab_Notebooks/lab_3_I...
# 1  /content/drive/MyDrive/Colab_Notebooks/lab_3_I...
# 2  /content/drive/MyDrive/Colab_Notebooks/lab_3_I...
# 3  /content/drive/MyDrive/Colab_Notebooks/lab_3_I...
# 4  /content/drive/MyDrive/Colab_Notebooks/lab_3_I...

# %% [markdown]
# And finally visualize the images with the corresponding segmentation masks:

# %%
class EndoscopyDataset(tc.utils.data.Dataset):
    def __init__(self, data_path ,csv_path, transforms=None, z_norm=False):
        self.csv_path = csv_path
        self.data_path = data_path
        self.dataframe = pd.read_csv(self.csv_path)

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        current_case = self.dataframe.iloc[idx]
        image_path = os.path.join(self.data_path, current_case["Image_Path"])
        mask_path = os.path.join(self.data_path, current_case["Mask_Path"])

        current_image = sitk.GetArrayFromImage(sitk.ReadImage(image_path)).astype(np.float32) #type imp forgot before
        current_mask = sitk.GetArrayFromImage(sitk.ReadImage(mask_path)).astype(np.float32) 
        min = np.amin(current_image[:,:,0]), np.amin(current_image[:,:,1]), np.amin(current_image[:,:,2])
        max = np.amax(current_image[:,:,0]), np.amax(current_image[:,:,1]), np.amax(current_image[:,:,2])

        #taking example from python slicing 
        current_image[:,:,0] = (current_image[:,:,0] - min[0]) / (max[0] - min[0])
        current_image[:,:,1] = (current_image[:,:,1] - min[1]) / (max[1] - min[1])
        current_image[:,:,2] = (current_image[:,:,2] - min[2]) / (max[2] - min[2])

        
        def resize(current_image): #resample resolution
          return tv.transforms.Resize((224, 224))(current_image)
        
        def gray(current_image): #grayscale
          return tv.transforms.Grayscale()(current_image)

        current_image = scipy.ndimage.zoom(current_image, (256/current_image.shape[0], 256/current_image.shape[1], 1), order=0)

        current_image = tv.transforms.Compose([tv.transforms.ToTensor()])(current_image)

        current_mask = scipy.ndimage.zoom(current_mask, (256/current_mask.shape[0], 256/current_mask.shape[1], 1), order=0)

        current_mask = color.rgb2gray(current_mask) 

        current_mask = np.expand_dims(current_mask, axis=-1)
        current_mask = (current_mask - np.amin(current_mask)) / (np.amax(current_mask) - np.amin(current_mask))

        current_mask = tv.transforms.Compose([tv.transforms.ToTensor()])(current_mask)
       
        return current_image, current_mask

# %%
shuffle = True
matched_dataset = EndoscopyDataset(data_path, matched_csv_path)
matched_dataloader = tc.utils.data.DataLoader(matched_dataset, batch_size=batch_size, shuffle=shuffle)
figure = plt.figure(figsize=(10, 10))

for images, masks in matched_dataloader:
    fig, axs = plt.subplots(2,4, figsize=(8, 4))
    for i in range(4):
        axs[0][i].set_xticks([]); 
        axs[0][i].set_yticks([]) 
        axs[1][i].set_xticks([]); 
        axs[1][i].set_yticks([])
        axs[0][i].imshow(np.transpose(images[i].numpy(), (1, 2, 0)))

        mask = np.transpose(masks[i].numpy(), (1, 2, 0))
        mask = mask.squeeze(axis=2)
        axs[1][i].imshow(mask, cmap='gray')
    break

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Congratulations, you have implemented several datasets dedicated to load medical images. You should be now able to implement you own dataset whenever necessary.
#
# After the laboratory you should:
# <ul>
#   <li> Understand the difference between Dataset and Dataloader objects.
#   <li> Implement your own Dataset object for a given medical dataset.
#   <li> Use the Dataloader object with any Dataset to load the data using the desired hyperparameters.
#   <li> Verify whether the Dataloader works and loads the data appropriately.
# </ul>
#
# During the next laboratory you are going to combine the knowledge from Laboratory 2 and Laboratory 3 to implement and train a simple convolutional neural network for medical image classification.
